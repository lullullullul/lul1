# %%
print("lol)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bdf7b98dd970> in <cell line: 1>()
# ----> 1 print(lol)
#
# NameError: name 'lol' is not defined
